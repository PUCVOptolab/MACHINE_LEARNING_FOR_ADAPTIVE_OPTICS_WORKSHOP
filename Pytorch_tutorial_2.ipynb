# %% [markdown]
# ![Pytorch_logo.png](data:image/png;base64,...)
# # Pytorch workshop parte II
#
# Felipe Guzman
#
# 19-06-2023

# %% [markdown]
# En la primera etapa, explicamos qué es un tensor, cómo operar con él y sus principales utilidades, sentando los principios básicos de los gradientes, el grafo computacional y la retropropagación.
#
# En esta parte, comenzaremos a abordar los problemas de optimización, el descenso de gradiente y el aprendizaje profundo.

# %% [markdown]
# ## Optimización convexa
#
# La optimización convexa es un campo de estudio en la optimización matemática que se enfoca en resolver problemas donde la función objetivo y las restricciones son funciones convexas. Se busca encontrar los valores de las variables que minimizan o maximizan la función objetivo, aprovechando las propiedades matemáticas de convexidad, como la convexidad del dominio y las curvas de nivel. La optimización convexa tiene aplicaciones en economía, estadística, aprendizaje automático y otras disciplinas, ofreciendo métodos eficientes y garantías teóricas de encontrar soluciones óptimas globales.
#
# ![images.png](data:image/png;base64,...)

# %% [markdown]
# ## Ejemplo de optimizacion básica
#
# Vamos a suponer un simple escenario. Tenemos el siguiente modelo matemático:
#
# $ y = f(x) = 3+2x+1x^3 $
#
# como es común en los problemas de optimizacion supervisados, desconocemos $f(x)$ pero sabes que dado un valor de $x_1$ sabemos su valor de salida $y_1 = f(x_1)$. Con esto en mente vamos a crear datos de entrenamiento en base a entradas y salidas:

# %%
import torch
device = torch.device('cuda')

x_train = torch.tensor([0.,1.,2.,3.,4.,5.],device=device,requires_grad=True)
y_train = torch.tensor([3.,6.,11.,18.,27.,38.],device=device,requires_grad=True)

print(x_train)
print(y_train)
# Out:
# tensor([0., 1., 2., 3., 4., 5.], device='cuda:0', requires_grad=True)
# tensor([ 3.,  6., 11., 18., 27., 38.], device='cuda:0', requires_grad=True)

# %% [markdown]
# Las suposiciones para este problema son que sabemos que $f(x)$ es un polinomio de orden 2, pero desconocemos los coeficientes. Por lo tanto, generaremos coeficientes con cualquier valor inicial.
#
# $ y = f(x) = w_0+w_1x+w_2x^2$

# %%
w0 = torch.tensor([0.2],device=device,requires_grad=True)
w1 = torch.tensor([5.],device=device,requires_grad=True)
w2 = torch.tensor([-0.1],device=device,requires_grad=True)

# %% [markdown]
# Si hacemos un primer calculo de $x=2$, vamos a notar que estamos muy lejos del valor esperado:

# %%
with torch.no_grad():
  y_cal = w0+w1*2+w2*2**2
  print(y_cal)
# Out:
# tensor([9.8000], device='cuda:0')

# %% [markdown]
# Notece que segun nuestros datos, para $x=2$, el valor de $y$ deberia ser igual 11. Lo otro interesante, es que los tensores w0,w1,w2 tienes gradientes activos, pero nuestro resultado no tiene gradiente. La funcion ```with toch.no_grad():``` permite realizar operaciones sin calcular el grafo.
#
# Ahora que sabemos que los valores que elegimos de $\mathbf{w}$ no son correctos, vamos a optimizarlos. Para esto vamos a definir un par de funciones:

# %%
def forward(x):
  y = w0 + w1*x + w2*x**2
  return(y)

def loss(y,y_hat):
  loss_cal = torch.mean((y-y_hat)**2)
  return(loss_cal)

# %% [markdown]
# Las funciones que vamos a utilizar son:
# * **forward()**: Esta es en la que ubicaremos nuestro modelo, para este ejemplo, es la propagacion de un modelo matematico, sin embargo mas adelante representara la propagacion de nuestro modelo de red neuronal convolucional. El principio es el mismo
#
# * **loss()**: Esta es la funcion de costo, como se menciono en los principios de optimizacion, idealmente se trata de una funcion convexa que queremos minimizar (es decir reducir el error). Para este ejemplo implementamos el error cuadratico medio (tambien llamado L2) y se define asi como $L_2 = || y-\hat{y} ||_2$. Recordar que esta funcion debe ser escalar.
#
#
# Nuestra funcion de optimizacion queda de la siguiente forma:
#
#
# $\hat{w}=\arg \min _{\boldsymbol{w}} \mathcal{L}(w)$
#
# ademas vamos a utilizar una variable $\lambda$ que llamaremos tasa de aprendizaje y el numero de epocas para entrenar

# %%
import torch
device = torch.device('cuda')

x_train = torch.tensor([0.,1.,2.,3.,4.,5.],device=device,requires_grad=True)
y_train = torch.tensor([3.,6.,11.,18.,27.,38.],device=device,requires_grad=True)

lamb = 0.002
Epochs = 15000

w0 = torch.tensor([0.2],device=device,requires_grad=True)
w1 = torch.tensor([5.],device=device,requires_grad=True)
w2 = torch.tensor([-0.1],device=device,requires_grad=True)

for epo in range(1,Epochs+1):

  # propagacion al modelo
  y_pred = forward(x_train)
  # Calcular error
  L = loss(y_train,y_pred)
  #Obtener gradientes
  L.backward()

  with torch.no_grad():
    w0 -= lamb*w0.grad
    w1 -= lamb*w1.grad
    w2 -= lamb*w2.grad

  # Reset gradients
  w0.grad.zero_()
  w1.grad.zero_()
  w2.grad.zero_()
  if epo % 500 == 0:
    print(f"funcion f(x) optimizada a f(x) = {w0.item():.2f} + {w1.item():.2f}*x + {w2.item():.2f}*x^2 en epoca {epo} Loss = {L.item():.6f}")
# Out:
# funcion f(x) optimizada a f(x) = 0.65 + 4.28*x + 0.61*x^2 en epoca 500 Loss = 1.313447
# funcion f(x) optimizada a f(x) = 1.12 + 3.76*x + 0.70*x^2 en epoca 1000 Loss = 0.808458
# funcion f(x) optimizada a f(x) = 1.52 + 3.38*x + 0.77*x^2 en epoca 1500 Loss = 0.499162
# funcion f(x) optimizada a f(x) = 1.84 + 3.08*x + 0.82*x^2 en epoca 2000 Loss = 0.308242
# funcion f(x) optimizada a f(x) = 2.09 + 2.85*x + 0.86*x^2 en epoca 2500 Loss = 0.190345
# funcion f(x) optimizada a f(x) = 2.28 + 2.67*x + 0.89*x^2 en epoca 3000 Loss = 0.117542
# funcion f(x) optimizada a f(x) = 2.44 + 2.52*x + 0.91*x^2 en epoca 3500 Loss = 0.072585
# funcion f(x) optimizada a f(x) = 2.56 + 2.41*x + 0.93*x^2 en epoca 4000 Loss = 0.044823
# funcion f(x) optimizada a f(x) = 2.65 + 2.32*x + 0.95*x^2 en epoca 4500 Loss = 0.027679
# funcion f(x) optimizada a f(x) = 2.73 + 2.25*x + 0.96*x^2 en epoca 5000 Loss = 0.017093
# funcion f(x) optimizada a f(x) = 2.78 + 2.20*x + 0.97*x^2 en epoca 5500 Loss = 0.010555
# funcion f(x) optimizada a f(x) = 2.83 + 2.16*x + 0.97*x^2 en epoca 6000 Loss = 0.006518
# funcion f(x) optimizada a f(x) = 2.87 + 2.12*x + 0.98*x^2 en epoca 6500 Loss = 0.004025
# funcion f(x) optimizada a f(x) = 2.90 + 2.10*x + 0.98*x^2 en epoca 7000 Loss = 0.002486
# funcion f(x) optimizada a f(x) = 2.92 + 2.08*x + 0.99*x^2 en epoca 7500 Loss = 0.001535
# funcion f(x) optimizada a f(x) = 2.94 + 2.06*x + 0.99*x^2 en epoca 8000 Loss = 0.000948
# funcion f(x) optimizada a f(x) = 2.95 + 2.05*x + 0.99*x^2 en epoca 8500 Loss = 0.000585
# funcion f(x) optimizada a f(x) = 2.96 + 2.04*x + 0.99*x^2 en epoca 9000 Loss = 0.000362
# funcion f(x) optimizada a f(x) = 2.97 + 2.03*x + 1.00*x^2 en epoca 9500 Loss = 0.000223
# funcion f(x) optimizada a f(x) = 2.98 + 2.02*x + 1.00*x^2 en epoca 10000 Loss = 0.000138
# funcion f(x) optimizada a f(x) = 2.98 + 2.02*x + 1.00*x^2 en epoca 10500 Loss = 0.000085
# funcion f(x) optimizada a f(x) = 2.98 + 2.01*x + 1.00*x^2 en epoca 11000 Loss = 0.000053
# funcion f(x) optimizada a f(x) = 2.99 + 2.01*x + 1.00*x^2 en epoca 11500 Loss = 0.000032
# funcion f(x) optimizada a f(x) = 2.99 + 2.01*x + 1.00*x^2 en epoca 12000 Loss = 0.000020
# funcion f(x) optimizada a f(x) = 2.99 + 2.01*x + 1.00*x^2 en epoca 12500 Loss = 0.000012
# funcion f(x) optimizada a f(x) = 2.99 + 2.01*x + 1.00*x^2 en epoca 13000 Loss = 0.000008
# funcion f(x) optimizada a f(x) = 3.00 + 2.00*x + 1.00*x^2 en epoca 13500 Loss = 0.000005
# funcion f(x) optimizada a f(x) = 3.00 + 2.00*x + 1.00*x^2 en epoca 14000 Loss = 0.000003
# funcion f(x) optimizada a f(x) = 3.00 + 2.00*x + 1.00*x^2 en epoca 14500 Loss = 0.000002
# funcion f(x) optimizada a f(x) = 3.00 + 2.00*x + 1.00*x^2 en epoca 15000 Loss = 0.000001

# %% [markdown]
# Como podemos ver en los resultados, para una tasa de aprendizaje de $0.002$ con un optimizador básico, le tomó 15.000 épocas alcanzar el óptimo del modelo.
#
# ## ¿Cómo logró este algoritmo llegar a la solución?
#
# Como se mencionó anteriormente, esta es una implementación muy básica del gradiente descendente. Los gradientes nos indican en qué dirección se reduce la función de costo, y con esta información podemos actualizar los parámetros a optimizar.
#
# Podemos expresar los gradientes de la siguiente manera:
#
# $\frac{\delta L}{\delta w} = \left[ \frac{\delta w}{\delta w_0},\frac{\delta w}{\delta w_1},\frac{\delta w}{\delta w_2} \right]$
#
# Luego los parametros se pueden actualizar de esta forma:
#
# $\hat{w_0} = w_0-\lambda \frac{\delta w}{\delta w_0}$,
#
# $\hat{w_1} = w_0-\lambda \frac{\delta w}{\delta w_1}$,
#
# $\hat{w_2} = w_0-\lambda \frac{\delta w}{\delta w_2}$

# %% [markdown]
# ## Optimizadores
#
# Si han leído literatura en ciencias de la computación, existen optimizadores que exploran métodos más efectivos para actualizar los parámetros entrenables utilizando los gradientes. Los más populares son el Descenso de Gradiente Estocástico (SGD) y Adam. Hay muchas variaciones de estos optimizadores y su éxito puede variar según la tarea (https://pytorch.org/docs/stable/optim.html).
#
# PyTorch ya incluye implementaciones de muchos de estos métodos, por lo que no es necesario implementarlos desde cero.
#
# Lo mismo ocurre con las funciones de costo, existen varias funciones de costo listas para utilizar dentro de la documentacion de pytorch pueden acceder a ellas (https://pytorch.org/docs/stable/nn.html)
#
# En este ejemplo repitiremos el ejercicio anteior, pero esta ves utilizando la funcion de costo MSE implementada por pytorch ademas de Adam.

# %%
import torch
import torch.nn as nn
device = torch.device('cuda')

x_train = torch.tensor([0.,1.,2.,3.,4.,5.],device=device,requires_grad=True)
y_train = torch.tensor([3.,6.,11.,18.,27.,38.],device=device,requires_grad=True)

w0 = torch.tensor([0.2],device=device,requires_grad=True)
w1 = torch.tensor([5.],device=device,requires_grad=True)
w2 = torch.tensor([-0.1],device=device,requires_grad=True)

lamb = 0.002
Epochs = 15000

loss = nn.MSELoss()
optimizer = torch.optim.Adam([w0,w1,w2], lr=lamb)

def forward(x):
  y = w0 + w1*x + w2*x**2
  return(y)

for epo in range(1,Epochs+1):

  # propagacion al modelo
  y_pred = forward(x_train)
  # Calcular error
  L = loss(y_train,y_pred)
  #Obtener gradientes
  L.backward()

  # update weights
  optimizer.step()

  # zero the gradients after updating
  optimizer.zero_grad()
  if epo % 500 == 0:
    print(f"funcion f(x) optimizada a f(x) = {w0.item():.2f} + {w1.item():.2f}*x + {w2.item():.2f}*x^2 en epoca {epo} Loss = {L.item():.6f}")
# Out:
# funcion f(x) optimizada a f(x) = 0.60 + 5.39*x + 0.34*x^2 en epoca 500 Loss = 2.716821
# funcion f(x) optimizada a f(x) = 0.55 + 5.28*x + 0.38*x^2 en epoca 1000 Loss = 2.488353
# funcion f(x) optimizada a f(x) = 0.53 + 5.12*x + 0.42*x^2 en epoca 1500 Loss = 2.236295
# funcion f(x) optimizada a f(x) = 0.57 + 4.92*x + 0.46*x^2 en epoca 2000 Loss = 1.965439
# funcion f(x) optimizada a f(x) = 0.70 + 4.69*x + 0.51*x^2 en epoca 2500 Loss = 1.673082
# funcion f(x) optimizada a f(x) = 0.90 + 4.43*x + 0.56*x^2 en epoca 3000 Loss = 1.362603
# funcion f(x) optimizada a f(x) = 1.14 + 4.13*x + 0.61*x^2 en epoca 3500 Loss = 1.048751
# funcion f(x) optimizada a f(x) = 1.43 + 3.80*x + 0.67*x^2 en epoca 4000 Loss = 0.752689
# funcion f(x) optimizada a f(x) = 1.72 + 3.46*x + 0.73*x^2 en epoca 4500 Loss = 0.495562
# funcion f(x) optimizada a f(x) = 2.02 + 3.12*x + 0.80*x^2 en epoca 5000 Loss = 0.293046
# funcion f(x) optimizada a f(x) = 2.29 + 2.81*x + 0.85*x^2 en epoca 5500 Loss = 0.151309
# funcion f(x) optimizada a f(x) = 2.54 + 2.53*x + 0.90*x^2 en epoca 6000 Loss = 0.065649
# funcion f(x) optimizada a f(x) = 2.73 + 2.31*x + 0.94*x^2 en epoca 6500 Loss = 0.022721
# funcion f(x) optimizada a f(x) = 2.86 + 2.16*x + 0.97*x^2 en epoca 7000 Loss = 0.005851
# funcion f(x) optimizada a f(x) = 2.94 + 2.07*x + 0.99*x^2 en epoca 7500 Loss = 0.001023
# funcion f(x) optimizada a f(x) = 2.98 + 2.02*x + 1.00*x^2 en epoca 8000 Loss = 0.000108
# funcion f(x) optimizada a f(x) = 3.00 + 2.01*x + 1.00*x^2 en epoca 8500 Loss = 0.000006
# funcion f(x) optimizada a f(x) = 3.00 + 2.00*x + 1.00*x^2 en epoca 9000 Loss = 0.000000
# funcion f(x) optimizada a f(x) = 3.00 + 2.00*x + 1.00*x^2 en epoca 9500 Loss = 0.000000
# funcion f(x) optimizada a f(x) = 3.00 + 2.00*x + 1.00*x^2 en epoca 10000 Loss = 0.000000
# funcion f(x) optimizada a f(x) = 3.00 + 2.00*x + 1.00*x^2 en epoca 10500 Loss = 0.000000
# funcion f(x) optimizada a f(x) = 3.00 + 2.00*x + 1.00*x^2 en epoca 11000 Loss = 0.000000
# funcion f(x) optimizada a f(x) = 3.00 + 2.00*x + 1.00*x^2 en epoca 11500 Loss = 0.000000
# funcion f(x) optimizada a f(x) = 3.00 + 2.00*x + 1.00*x^2 en epoca 12000 Loss = 0.000000
# funcion f(x) optimizada a f(x) = 3.00 + 2.00*x + 1.00*x^2 en epoca 12500 Loss = 0.000000
# funcion f(x) optimizada a f(x) = 3.00 + 2.00*x + 1.00*x^2 en epoca 13000 Loss = 0.000000
# funcion f(x) optimizada a f(x) = 3.00 + 2.00*x + 1.00*x^2 en epoca 13500 Loss = 0.000000
# funcion f(x) optimizada a f(x) = 3.00 + 2.00*x + 1.00*x^2 en epoca 14000 Loss = 0.000000
# funcion f(x) optimizada a f(x) = 3.00 + 2.00*x + 1.00*x^2 en epoca 14500 Loss = 0.000000
# funcion f(x) optimizada a f(x) = 3.00 + 2.00*x + 1.00*x^2 en epoca 15000 Loss = 0.000000

# %% [markdown]
# Como pueden observar, al utilizar un optimizador más avanzado, el problema converge mucho más rápido. En la época 9000, prácticamente está resuelto.

# %% [markdown]
# # Notacion tensorial y redes neuronales
#
# Para utilizar exitosamente las redes neuronales, primero debemos entender cómo PyTorch procesa los tensores y sus operaciones. Por ahora, trabajaremos con tensores de máximo 4 dimensiones.
#
# Cada dimensión de un tensor tiene un contexto asignado en el cual se realizan operaciones como fft2, convolución, entre otras. El orden por defecto asignado en PyTorch es:
#
# $\operatorname{Tensor} = B\times C\times H\times W$,
#
# $B$: corresponde al batch, es decir, diferentes datos agrupados en un "paquete". Las operaciones de PyTorch iteran a través del batch.
#
# $C$: corresponde al canal (channel), y su significado puede variar según el contexto. En imágenes, generalmente se refiere a la "profundidad", donde el canal representa los colores rojo, verde y azul en imágenes a color. En imágenes monocromáticas, $C=1$. También se puede interpretar como frames de video en el caso de videos monocromáticos, o como diferentes frecuencias espectrales en otros contextos.
#
# $H, W$: corresponden a la resolución de la imagen.
#
# Si se trabajan con vectores de datos, como series temporales u otro tipo de arreglo 1D, el tensor se puede representar como $\operatorname{Tensor} = B\times 1\times H$ o también $B\times H \times 1$, dependiendo del uso que se le dará a los tensores. Lo importante es que el batch siempre debe ir en primer lugar.
#
#
# ## Ejemplo de operación en batch
#
# Retomemos el ejemplo de la transformada de fourier. Segun la documentacion de la implementacion de pytorch (https://pytorch.org/docs/stable/generated/torch.fft.fft2.html), la fft2d se realiza en las dimensiones $H$ y $W$ por lo que iterar sobre $B$ dara el mismo resultado.

# %%
import torch
import time
device = torch.device('cuda')
A = torch.ones(80,1,512,512,device=device)

# %% [markdown]
# para este ejemplo el tensor $A$ consiste en 80 imagenes monocromaticas de $512\times 512$

# %%
# Metodo iterativo
R1 = torch.zeros(80,1,512,512,dtype=torch.complex64,device=device)

st_iter = time.time()
for k in range(80):
  R1[k] = torch.fft.fft2(A[k])
fn_iter = time.time()

iterative_time = fn_iter - st_iter

st_batc = time.time()
R2 = torch.fft.fft2(A)
fn_batc = time.time()

batch_time = fn_iter - st_iter

print(f"Iterative time {iterative_time*1000} ms")
print(f"batch     time {batch_time*1000} ms")

print(f"mean diference {torch.mean(R1-R2)}")
# Out:
# Iterative time 6.632804870605469 ms
# batch     time 6.632804870605469 ms
# mean diference 0j

# %% [markdown]
# Como se puede observar, ambos métodos están bien optimizados y son análogos. Sin embargo, es preferible operar en batch, ya que simplifica la programación al requerir solo una línea de código para obtener el resultado.

# %% [markdown]
# Con la notación tensorial revisada, estamos listos para comenzar a analizar redes neuronales. Discutiremos las diferentes arquitecturas, pero nos enfocaremos en programar redes neuronales convolucionales.

# %% [markdown]
# ## Perceptrón
#
# El perceptrón es una unidad básica de una red neuronal que realiza una combinación lineal de las entradas y aplica una función de activación para producir una salida. Utiliza pesos y umbrales ajustables para asignar diferentes pesos a las entradas y decidir si la salida es activada o no. Es capaz de aprender a través del ajuste iterativo de los pesos en función de los errores cometidos. El perceptrón es un clasificador binario linealmente separable, es decir, puede separar dos conjuntos de datos mediante una línea o un hiperplano en el espacio de características.
#
# ![0_LJBO8UbtzK_SKMog.png](data:image/png;base64,...)

# %% [markdown]
# # Convolución
#
# La convolución en el contexto del aprendizaje profundo, específicamente en las redes neuronales convolucionales, es una operación esencial que utiliza filtros deslizantes para extraer características relevantes de los datos de entrada. Esta operación permite capturar relaciones espaciales y locales en imágenes o volúmenes de datos, y ha demostrado ser muy efectiva en tareas de visión por computadora, como clasificación de imágenes, detección de objetos y segmentación.
#
# ![convolution-1.png](data:image/png;base64,...)

# %% [markdown]
# ## Funciones de activación
#
# Las funciones de activación son componentes clave en las redes neuronales, ya que introducen la capacidad de no linealidad en el modelo. Estas funciones se aplican a la salida de una neurona y determinan si esa neurona se activa o no.
#
# Una de las funciones de activación más comunes es la función ReLU (Rectified Linear Unit), que activa la neurona si el valor de entrada es mayor que cero y la desactiva si es menor o igual a cero. La función ReLU es ampliamente utilizada debido a su simplicidad y capacidad para lidiar con el problema del desvanecimiento del gradiente.
#
# Otra función de activación popular es la función sigmoide, que produce una salida en el rango de 0 a 1, lo que la hace adecuada para problemas de clasificación binaria. Sin embargo, la función sigmoide puede sufrir del problema del desvanecimiento del gradiente en redes neuronales profundas.
#
# También se utiliza la función tanh (tangente hiperbólica), que produce una salida en el rango de -1 a 1. La función tanh es simétrica alrededor de cero y puede ser útil en ciertos escenarios.
#
# Además de estas funciones, existen otras como la función softmax para clasificación multiclase, la función Leaky ReLU para abordar el problema de la activación "muerta" en ReLU, y la función ELU (Exponential Linear Unit) que combina aspectos de ReLU y sigmoide.
#
# La elección de la función de activación depende del problema y las características de los datos. Las funciones de activación permiten a las redes neuronales aprender representaciones no lineales y capturar relaciones complejas en los datos, lo que las hace fundamentales en el éxito de las redes neuronales.

# %% [markdown]
# # Ejercicio: Deblurring de imagenes con capa convolucional
#
# Tenemos el siguiente escenario: los sistemas de imagen se pueden representar como una convolución de la distribución de luz en el sensor, donde el kernel representa el sistema óptico caracterizado que añade deformaciones, desenfoque, entre otras cosas.
#
# Los algoritmos de deblurring intentan mejorar la calidad de una imagen que ha sido distorsionada por distintas fuentes, las cuales pueden ser modeladas como una convolución.
#
# Vamos a simular una deformación de lente y comprobar si una capa convolucional es capaz de reconstruir la imagen optimizando el kernel de convolución.

# %% [markdown]
# * Agregar imagen a la carpeta

# %%
# !gdown 1tUt2G9laNdspHkUq2LZHRSMf7FR10Lc6
from PIL import Image
# importar imagen desde directorio
image = Image.open('shrek.jpg')
# plot
display(image)
print(image.size)
# Out:
# /bin/bash: line 1: gdown: command not found
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 4
#       2 from PIL import Image
#       3 # importar imagen desde directorio
# ----> 4 image = Image.open('shrek.jpg')
#       5 # plot
#       6 display(image)
#
# File ~/miniconda3/envs/nn/lib/python3.10/site-packages/PIL/Image.py:3469, in open(fp, mode, formats)
#    3466     filename = os.path.realpath(os.fspath(fp))
#    3468 if filename:
# -> 3469     fp = builtins.open(filename, "rb")
#    3470     exclusive_fp = True
#    3471 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data2/bgonzalez/desktop/MACHINE_LEARNING_FOR_ADAPTIVE_OPTICS_WORKSHOP/shrek.jpg'

# %% [markdown]
# * Se debe transformar a un arreglo numpy y luego pasar a pytorch.Recordar que para operar con el tensor, se debe expresar en su notación, en este ejemplo como es una imagen a color, debe quedar con dimensiones $1\times 3\times 256\times 256$

# %%
import numpy as np
import torch
device = torch.device('cuda')
data = np.asarray(image)
input_tensor = torch.from_numpy(data).to(device).float()
print(input_tensor.shape)

# Adaptar dimensioines
input_tensor = torch.unsqueeze(input_tensor,0)
print(input_tensor.shape)

input_tensor = input_tensor.permute(0,3,1,2)
print(input_tensor.shape)
# Out:
# <ipython-input-3-f8fd008762a2>:5: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   input_tensor = torch.from_numpy(data).to(device).float()
# torch.Size([256, 256, 3])
# torch.Size([1, 256, 256, 3])
# torch.Size([1, 3, 256, 256])

# %% [markdown]
# Ahora supongamos que la imagen es corrompida por un kernel desconocido. El kernel debe tener la misma cantidad de canales que la imagen. Entonces si diseñamos un kernel de aberracion de  $3 \times 3$ y asumimos que afecta de la misma forma a los 3 colores debe quedar $1\times 1\times 3\times 3$.

# %%
import torch.nn.functional as F

grado_distorsion = 7
kernel =  torch.eye(grado_distorsion).to(device) /grado_distorsion
print(kernel)
print(kernel.shape)
kernel = torch.unsqueeze(torch.unsqueeze(kernel,0),0).float()
print(kernel.shape)

pad = grado_distorsion//2

corrR = F.conv2d(input_tensor[:,0:1],kernel,padding=pad)
corrG = F.conv2d(input_tensor[:,1:2],kernel,padding=pad)
corrB = F.conv2d(input_tensor[:,2:],kernel,padding=pad)
corrupted = torch.cat((corrR,corrG,corrB),dim=1)
print(corrupted.shape)
# Out:
# tensor([[0.1429, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.1429, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.1429, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.1429, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.1429, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1429, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1429]],
#        device='cuda:0')
# torch.Size([7, 7])
# torch.Size([1, 1, 7, 7])
# torch.Size([1, 3, 256, 256])

# %% [markdown]
# Para ver el resultado de la imagen, podemos usar librerias de python para plotear imagenes (como la usada anteriormente) sin embargo para hacer esto la imagene debe estar alojada en cpu y debe estar en sus dimensiones naturales ($H \times W \times C$). Incorporaremos todo este procedimiento en una funcion:

# %%
import torch
import matplotlib.pyplot as plt

def plot_tensor(tensor):
    # Se mueve el tensor de gpu a cpu
    tensor = tensor.cpu()
    # se transforma a arreglo numpy
    array = tensor.numpy()
    # se deja en dimensiones naturales (H,W,C)
    array = array[0].transpose(1, 2, 0)
    # graficar con matplotlib
    plt.imshow(array)
    plt.show()

# %% [markdown]
# Con la funcion podemos ver el resultado de la aberración

# %%
print("input")
plt.figure(figsize=(3, 3))
plot_tensor(input_tensor/255)

print("Imagen corrompida")
plt.figure(figsize=(3, 3))
plot_tensor(corrupted/255)
# Out:
# input
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Imagen corrompida

# %% [markdown]
# La aberración aplicada es el desenfoque de movimiento (motion blur) y puede empeorarla al umentar el valor de ```grado_distorsion ```. Ahora utilizaremos los mismos conceptos del ejemplo anterior, pero en esta ocasión nuestro modelo será una capa convolucional. De esta manera, podremos determinar si es posible reenfocar la imagen

# %%
import torch
import torch.nn as nn
import numpy as np
from PIL import Image
device = torch.device('cuda')

class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        self.conv1 = nn.Conv2d(3, 3, 5,padding=2)

    def forward(self, x):
        # -> n, 3, 32, 32
        x = self.conv1(x)
        return x


lamb = 0.0005
Epochs = 12000

# Parametros del entrenamiento
model = ConvNet().to(device)
loss = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lamb)
loss_val = []
for epo in range(1,Epochs+1):

  # propagacion al modelo
  out_tensor = model(corrupted)
  # Calcular error
  L = loss(input_tensor,out_tensor)
  #Obtener gradientes
  L.backward()

  # update weights
  optimizer.step()

  # zero the gradients after updating
  optimizer.zero_grad()
  if epo % 1200 == 0:
    print(f" epoca {epo} Loss = {L.item():.6f} - learning_rate = {lamb:.8f}")
  if epo % 100 == 0 and epo>0:
    lamb = lamb*0.95
    optimizer = torch.optim.Adam(model.parameters(), lr=lamb)

  # Guardar valores de loss por epoca
  loss_val.append(L.item())
# Out:
#  epoca 1200 Loss = 278.736298 - learning_rate = 0.00028440
#  epoca 2400 Loss = 247.412170 - learning_rate = 0.00015368
#  epoca 3600 Loss = 237.779785 - learning_rate = 0.00008304
#  epoca 4800 Loss = 233.836914 - learning_rate = 0.00004487
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-b58083a0e48f> in <cell line: 26>()
#      34
#      35   # update weights
# ---> 36   optimizer.step()
#      37
#      38   # zero the gradients after updating
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     267             self, *_ = args
#     268             profile_name = "Optimizer.step#{}.step".format(self.__class__.__name__)
# --> 269             with torch.autograd.profiler.record_function(profile_name):
#     270                 # call optimizer step pre hooks
#     271                 for pre_hook in chain(_global_optimizer_pre_hooks.values(), self._optimizer_step_pre_hooks.values()):
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/profiler.py in __exit__(self, exc_type, exc_value, traceback)
#     505         if not torch.jit.is_scripting():
#     506             with torch._C.DisableTorchFunctionSubclass():
# --> 507                 torch.ops.profiler._record_function_exit._RecordFunction(record)
#     508         else:
#     509             torch.ops.profiler._record_function_exit(record)
#
# /usr/local/lib/python3.10/dist-packages/torch/_ops.py in __call__(self, *args, **kwargs)
#     284         )
#     285
# --> 286     def __call__(self, *args, **kwargs):
#     287         return self._op(*args, **kwargs or {})
#     288
#
# KeyboardInterrupt:

# %% [markdown]
# Podemos observar la evolución del aprendizaje al graficar la función de pérdida.

# %%
import numpy as np
import matplotlib.pyplot as plt

#Eje x
x = np.arange(len(loss_val))+1

plt.figure(figsize=(12, 3))
# graficar loss
plt.plot(x, loss_val)
plt.yscale('log')
# añadir titulos
plt.xlabel('Epoca')
plt.ylabel('MSE')
plt.title('Entrenamiento shrek')

# Display
plt.show()

# %% [markdown]
# Al observar la curva, se puede apreciar un comportamiento típico en el aprendizaje automático. Las redes neuronales son capaces de aprender hasta que llega un punto en el que se estancan. Esto puede deberse a que han alcanzado el mínimo global (el mejor resultado posible) o se han estancado en un mínimo local. Dependiendo de la calidad del resultado, es posible diferenciar entre ambos casos.
#
# La capacidad de una red neuronal para alcanzar una buena solución depende de diversos factores, como la calidad de la base de datos utilizada, la arquitectura empleada y los hiperparámetros seleccionados. Existen numerosas estrategias que se pueden probar para mejorar estos resultados.
#
# Ahora veamos el resultado del entrenamiento.
# Para evitar que el modelo calcule los gradientes se deben congelar las capas. Este paso no es escencial pero es eficiente en consumo de memoria.

# %%
for param in model.parameters():
    param.requires_grad = False

corrected = model(corrupted.detach())

print("                   Imagen original  -            Imagen distorsionada         -              Reconstruccion de CNN")
plt.figure(figsize=(12, 12))
plot_tensor(torch.cat((input_tensor,corrupted,corrected),dim=3)/255)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#                    Imagen original  -            Imagen distorsionada         -              Reconstruccion de CNN

# %% [markdown]
# A pesar de que la aberración se representa con una capa convolucional, entrenar dicha capa por sí sola no es suficiente para revertir el proceso, ya que la deconvolución es un proceso más complejo. Sin embargo, podríamos explorar si aumentar el tamaño del modelo nos permite obtener mejores resultados.

# %%
import torch
import torch.nn as nn
import numpy as np
from PIL import Image
device = torch.device('cuda')

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()

        # Encoder
        self.encoder_conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1)
        self.encoder_pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.encoder_conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.encoder_pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        # Decoder
        self.decoder_upconv1 = nn.ConvTranspose2d(32, 16, kernel_size=2, stride=2)
        self.decoder_conv1 = nn.Conv2d(16, 16, kernel_size=3, stride=1, padding=1)
        self.decoder_upconv2 = nn.ConvTranspose2d(16, 3, kernel_size=2, stride=2)
        self.decoder_conv2 = nn.Conv2d(3, 3, kernel_size=3, stride=1, padding=1)

    def forward(self, x):
        # Encoder
        x1 = self.encoder_conv1(x)
        x1p = self.encoder_pool1(x1)
        x2 = self.encoder_conv2(x1p)
        x2p = self.encoder_pool2(x2)

        # Decoder
        x_up1 = self.decoder_upconv1(x2p)
        x3 = self.decoder_conv1(x_up1)
        x_up2 = self.decoder_upconv2(x3)
        x_out = self.decoder_conv2(x_up2)

        return x_out


lamb = 0.006
Epochs = 12000

# Parametros del entrenamiento
model = UNet().to(device)
loss = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lamb)
loss_val = []
for epo in range(1,Epochs+1):

  # propagacion al modelo
  out_tensor = model(corrupted)
  # Calcular error
  L = loss(input_tensor,out_tensor)
  #Obtener gradientes
  L.backward()

  # update weights
  optimizer.step()

  # zero the gradients after updating
  optimizer.zero_grad()
  if epo % 1200 == 0:
    print(f" epoca {epo} Loss = {L.item():.6f} - learning_rate = {lamb:.8f}")
  if epo % 100 == 0 and epo>0:
    lamb = lamb*0.97
    optimizer = torch.optim.Adam(model.parameters(), lr=lamb)

  # Guardar valores de loss por epoca
  loss_val.append(L.item())
# Out:
#  epoca 1200 Loss = 194.506683 - learning_rate = 0.00429181
#  epoca 2400 Loss = 146.111633 - learning_rate = 0.00297784
#  epoca 3600 Loss = 102.488129 - learning_rate = 0.00206615
#  epoca 4800 Loss = 80.676147 - learning_rate = 0.00143358
#  epoca 6000 Loss = 71.678040 - learning_rate = 0.00099468
#  epoca 7200 Loss = 65.911430 - learning_rate = 0.00069015
#  epoca 8400 Loss = 61.533745 - learning_rate = 0.00047886
#  epoca 9600 Loss = 58.772652 - learning_rate = 0.00033225
#  epoca 10800 Loss = 56.782166 - learning_rate = 0.00023053
#  epoca 12000 Loss = 55.150936 - learning_rate = 0.00015995

# %%
import numpy as np
import matplotlib.pyplot as plt

#Eje x
x = np.arange(len(loss_val))+1

plt.figure(figsize=(12, 3))
# graficar loss
plt.plot(x, loss_val)
plt.yscale('log')
# añadir titulos
plt.xlabel('Epoca')
plt.ylabel('MSE')
plt.title('Entrenamiento shrek')

# Display
plt.show()

# %% [markdown]
# Si observamos la curva, tiene un comportamiento similar, sin embargo esta vez el error final es mucho menor que el caso anterior, es decir, ahora la reconstruccion debe ser mejor. Veamos el resultado:

# %%
for param in model.parameters():
    param.requires_grad = False

corrected = model(corrupted.detach())

print("                   Imagen original  -            Imagen distorsionada         -              Reconstruccion de CNN")
plt.figure(figsize=(12, 12))
plot_tensor(torch.cat((input_tensor,corrupted,corrected),dim=3)/255)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#                    Imagen original  -            Imagen distorsionada         -              Reconstruccion de CNN

# %% [markdown]
# Si bien no es perfecta, definitivamente esta reconstruccion es mucho mejor.
#
# Notemos ahora que entrenamos con esta unica imagen, ¿Será posible que pueda reconstruir otra imagen?

# %%
# !gdown 1tTzLO3PIMwg8stiHoEV3tSY3_u2qRK_a
from PIL import Image
# importar imagen desde directorio
image = Image.open('mr_inc.jpg')
# plot
display(image)
print(image.size)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tTzLO3PIMwg8stiHoEV3tSY3_u2qRK_a
# To: /content/mr_inc.jpg
# 100% 11.6k/11.6k [00:00<00:00, 51.4MB/s]
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>
# (256, 256)

# %%
import numpy as np
import torch
import torch.nn.functional as F
data = np.asarray(image)
device = torch.device('cuda')
input_tensor = torch.from_numpy(data).to(device).float()
# Adaptar dimensioines
input_tensor = torch.unsqueeze(input_tensor,0)
input_tensor = input_tensor.permute(0,3,1,2)


kernel =  torch.eye(grado_distorsion).to(device) /grado_distorsion
kernel = torch.unsqueeze(torch.unsqueeze(kernel,0),0).float()

corrR = F.conv2d(input_tensor[:,0:1],kernel,padding=pad)
corrG = F.conv2d(input_tensor[:,1:2],kernel,padding=pad)
corrB = F.conv2d(input_tensor[:,2:],kernel,padding=pad)
corrupted = torch.cat((corrR,corrG,corrB),dim=1)
print(corrupted.shape)
# Out:
# torch.Size([1, 3, 256, 256])

# %%
for param in model.parameters():
    param.requires_grad = False

corrected = model(corrupted.detach())

print("                   Imagen original  -            Imagen distorsionada         -              Reconstruccion de CNN")
plt.figure(figsize=(12, 12))
plot_tensor(torch.cat((input_tensor,corrupted,corrected),dim=3)/255)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-79a8b2f40c7f> in <cell line: 1>()
# ----> 1 for param in model.parameters():
#       2     param.requires_grad = False
#       3
#       4 corrected = model(corrupted.detach())
#       5
#
# NameError: name 'model' is not defined

# %% [markdown]
# Puedes notar que en este caso la red no es capaz de reconstruir la imagen. Esto se debe a que al entrenar únicamente con una imagen, la red ha sufrido de sobreajuste (overfitting) y se ha especializado en reconstruir esa imagen específica.
#
# Una de las formas más efectivas de combatir el sobreajuste es entrenar el modelo con una base de datos que tenga una diversidad adecuada. Esto permite que la red neuronal aprenda patrones generales en lugar de memorizar detalles específicos de una sola imagen. Al exponer el modelo a una variedad de ejemplos, se promueve una mejor generalización y capacidad de reconstrucción en diferentes escenarios.
#
#
# En este ultimo ejercicio de este taller, haremos un entrenamiento estandar de regresion con un dataset de imagenes.

# %% [markdown]
# # Preparar dataset
#
# Bajaremos un pequeño dataset de varias caras de famosos de un tamaño de $256\times 256$, esto a modo de simplificar el procesamiento de las imagenes. En teoria, al usar un modelo neuronal convolucional como UNET, la red puede procesar con resoluciones espaciales arbitrarias.

# %%
# !gdown 1tAK7DMa7GzD0i5FRydtUNJVTQXYj4Fpx
# !unzip celeba_hq_256.zip -d dataset
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tAK7DMa7GzD0i5FRydtUNJVTQXYj4Fpx
# To: /content/celeba_hq_256.zip
# 100% 6.58M/6.58M [00:00<00:00, 41.6MB/s]
# Archive:  celeba_hq_256.zip
#   inflating: dataset/celeba_hq_256/00000.jpg
#   inflating: dataset/celeba_hq_256/00001.jpg
#   inflating: dataset/celeba_hq_256/00002.jpg
#   inflating: dataset/celeba_hq_256/00003.jpg
#   inflating: dataset/celeba_hq_256/00004.jpg
#   inflating: dataset/celeba_hq_256/00005.jpg
#   inflating: dataset/celeba_hq_256/00006.jpg
#   inflating: dataset/celeba_hq_256/00007.jpg
#   inflating: dataset/celeba_hq_256/00008.jpg
#   inflating: dataset/celeba_hq_256/00009.jpg
#   inflating: dataset/celeba_hq_256/00010.jpg
#   inflating: dataset/celeba_hq_256/00011.jpg
#   inflating: dataset/celeba_hq_256/00012.jpg
#   inflating: dataset/celeba_hq_256/00013.jpg
#   inflating: dataset/celeba_hq_256/00014.jpg
#   inflating: dataset/celeba_hq_256/00015.jpg
#   inflating: dataset/celeba_hq_256/00016.jpg
#   inflating: dataset/celeba_hq_256/00017.jpg
#   inflating: dataset/celeba_hq_256/00018.jpg
#   inflating: dataset/celeba_hq_256/00019.jpg
#   inflating: dataset/celeba_hq_256/00020.jpg
#   inflating: dataset/celeba_hq_256/00021.jpg
#   inflating: dataset/celeba_hq_256/00022.jpg
#   inflating: dataset/celeba_hq_256/00023.jpg
#   inflating: dataset/celeba_hq_256/00024.jpg
#   inflating: dataset/celeba_hq_256/00025.jpg
#   inflating: dataset/celeba_hq_256/00026.jpg
#   inflating: dataset/celeba_hq_256/00027.jpg
#   inflating: dataset/celeba_hq_256/00028.jpg
#   inflating: dataset/celeba_hq_256/00029.jpg
#   inflating: dataset/celeba_hq_256/00030.jpg
#   inflating: dataset/celeba_hq_256/00031.jpg
#   inflating: dataset/celeba_hq_256/00032.jpg
#   inflating: dataset/celeba_hq_256/00033.jpg
#   inflating: dataset/celeba_hq_256/00034.jpg
#   inflating: dataset/celeba_hq_256/00035.jpg
#   inflating: dataset/celeba_hq_256/00036.jpg
#   inflating: dataset/celeba_hq_256/00037.jpg
#   inflating: dataset/celeba_hq_256/00038.jpg
#   inflating: dataset/celeba_hq_256/00039.jpg
#   inflating: dataset/celeba_hq_256/00040.jpg
#   inflating: dataset/celeba_hq_256/00041.jpg
#   inflating: dataset/celeba_hq_256/00042.jpg
#   inflating: dataset/celeba_hq_256/00043.jpg
#   inflating: dataset/celeba_hq_256/00044.jpg
#   inflating: dataset/celeba_hq_256/00045.jpg
#   inflating: dataset/celeba_hq_256/00046.jpg
#   inflating: dataset/celeba_hq_256/00047.jpg
#   inflating: dataset/celeba_hq_256/00048.jpg
#   inflating: dataset/celeba_hq_256/00049.jpg
#   inflating: dataset/celeba_hq_256/00050.jpg
#   inflating: dataset/celeba_hq_256/00051.jpg
#   inflating: dataset/celeba_hq_256/00052.jpg
#   inflating: dataset/celeba_hq_256/00053.jpg
#   inflating: dataset/celeba_hq_256/00054.jpg
#   inflating: dataset/celeba_hq_256/00055.jpg
#   inflating: dataset/celeba_hq_256/00056.jpg
#   inflating: dataset/celeba_hq_256/00057.jpg
#   inflating: dataset/celeba_hq_256/00058.jpg
#   inflating: dataset/celeba_hq_256/00059.jpg
#   inflating: dataset/celeba_hq_256/00060.jpg
#   inflating: dataset/celeba_hq_256/00061.jpg
#   inflating: dataset/celeba_hq_256/00062.jpg
#   inflating: dataset/celeba_hq_256/00063.jpg
#   inflating: dataset/celeba_hq_256/00064.jpg
#   inflating: dataset/celeba_hq_256/00065.jpg
#   inflating: dataset/celeba_hq_256/00066.jpg
#   inflating: dataset/celeba_hq_256/00067.jpg
#   inflating: dataset/celeba_hq_256/00068.jpg
#   inflating: dataset/celeba_hq_256/00069.jpg
#   inflating: dataset/celeba_hq_256/00070.jpg
#   inflating: dataset/celeba_hq_256/00071.jpg
#   inflating: dataset/celeba_hq_256/00072.jpg
#   inflating: dataset/celeba_hq_256/00073.jpg
#   inflating: dataset/celeba_hq_256/00074.jpg
#   inflating: dataset/celeba_hq_256/00075.jpg
#   inflating: dataset/celeba_hq_256/00076.jpg
#   inflating: dataset/celeba_hq_256/00077.jpg
#   inflating: dataset/celeba_hq_256/00078.jpg
#   inflating: dataset/celeba_hq_256/00079.jpg
#   inflating: dataset/celeba_hq_256/00080.jpg
#   inflating: dataset/celeba_hq_256/00081.jpg
#   inflating: dataset/celeba_hq_256/00082.jpg
#   inflating: dataset/celeba_hq_256/00083.jpg
#   inflating: dataset/celeba_hq_256/00084.jpg
#   inflating: dataset/celeba_hq_256/00085.jpg
#   inflating: dataset/celeba_hq_256/00086.jpg
#   inflating: dataset/celeba_hq_256/00087.jpg
#   inflating: dataset/celeba_hq_256/00088.jpg
#   inflating: dataset/celeba_hq_256/00089.jpg
#   inflating: dataset/celeba_hq_256/00090.jpg
#   inflating: dataset/celeba_hq_256/00091.jpg
#   inflating: dataset/celeba_hq_256/00092.jpg
#   inflating: dataset/celeba_hq_256/00093.jpg
#   inflating: dataset/celeba_hq_256/00094.jpg
#   inflating: dataset/celeba_hq_256/00095.jpg
#   inflating: dataset/celeba_hq_256/00096.jpg
#   inflating: dataset/celeba_hq_256/00097.jpg
#   inflating: dataset/celeba_hq_256/00098.jpg
#   inflating: dataset/celeba_hq_256/00099.jpg
#   inflating: dataset/celeba_hq_256/00100.jpg
#   inflating: dataset/celeba_hq_256/00101.jpg
#   inflating: dataset/celeba_hq_256/00102.jpg
#   inflating: dataset/celeba_hq_256/00103.jpg
#   inflating: dataset/celeba_hq_256/00104.jpg
#   inflating: dataset/celeba_hq_256/00105.jpg
#   inflating: dataset/celeba_hq_256/00106.jpg
#   inflating: dataset/celeba_hq_256/00107.jpg
#   inflating: dataset/celeba_hq_256/00108.jpg
#   inflating: dataset/celeba_hq_256/00109.jpg
#   inflating: dataset/celeba_hq_256/00110.jpg
#   inflating: dataset/celeba_hq_256/00111.jpg
#   inflating: dataset/celeba_hq_256/00112.jpg
#   inflating: dataset/celeba_hq_256/00113.jpg
#   inflating: dataset/celeba_hq_256/00114.jpg
#   inflating: dataset/celeba_hq_256/00115.jpg
#   inflating: dataset/celeba_hq_256/00116.jpg
#   inflating: dataset/celeba_hq_256/00117.jpg
#   inflating: dataset/celeba_hq_256/00118.jpg
#   inflating: dataset/celeba_hq_256/00119.jpg
#   inflating: dataset/celeba_hq_256/00120.jpg
#   inflating: dataset/celeba_hq_256/00121.jpg
#   inflating: dataset/celeba_hq_256/00122.jpg
#   inflating: dataset/celeba_hq_256/00123.jpg
#   inflating: dataset/celeba_hq_256/00124.jpg
#   inflating: dataset/celeba_hq_256/00125.jpg
#   inflating: dataset/celeba_hq_256/00126.jpg
#   inflating: dataset/celeba_hq_256/00127.jpg
#   inflating: dataset/celeba_hq_256/00128.jpg
#   inflating: dataset/celeba_hq_256/00129.jpg
#   inflating: dataset/celeba_hq_256/00130.jpg
#   inflating: dataset/celeba_hq_256/00131.jpg
#   inflating: dataset/celeba_hq_256/00132.jpg
#   inflating: dataset/celeba_hq_256/00133.jpg
#   inflating: dataset/celeba_hq_256/00134.jpg
#   inflating: dataset/celeba_hq_256/00135.jpg
#   inflating: dataset/celeba_hq_256/00136.jpg
#   inflating: dataset/celeba_hq_256/00137.jpg
#   inflating: dataset/celeba_hq_256/00138.jpg
#   inflating: dataset/celeba_hq_256/00139.jpg
#   inflating: dataset/celeba_hq_256/00140.jpg
#   inflating: dataset/celeba_hq_256/00141.jpg
#   inflating: dataset/celeba_hq_256/00142.jpg
#   inflating: dataset/celeba_hq_256/00143.jpg
#   inflating: dataset/celeba_hq_256/00144.jpg
#   inflating: dataset/celeba_hq_256/00145.jpg
#   inflating: dataset/celeba_hq_256/00146.jpg
#   inflating: dataset/celeba_hq_256/00147.jpg
#   inflating: dataset/celeba_hq_256/00148.jpg
#   inflating: dataset/celeba_hq_256/00149.jpg
#   inflating: dataset/celeba_hq_256/00150.jpg
#   inflating: dataset/celeba_hq_256/00151.jpg
#   inflating: dataset/celeba_hq_256/00152.jpg
#   inflating: dataset/celeba_hq_256/00153.jpg
#   inflating: dataset/celeba_hq_256/00154.jpg
#   inflating: dataset/celeba_hq_256/00155.jpg
#   inflating: dataset/celeba_hq_256/00156.jpg
#   inflating: dataset/celeba_hq_256/00157.jpg
#   inflating: dataset/celeba_hq_256/00158.jpg
#   inflating: dataset/celeba_hq_256/00159.jpg
#   inflating: dataset/celeba_hq_256/00160.jpg
#   inflating: dataset/celeba_hq_256/00161.jpg
#   inflating: dataset/celeba_hq_256/00162.jpg
#   inflating: dataset/celeba_hq_256/00163.jpg
#   inflating: dataset/celeba_hq_256/00164.jpg
#   inflating: dataset/celeba_hq_256/00165.jpg
#   inflating: dataset/celeba_hq_256/00166.jpg
#   inflating: dataset/celeba_hq_256/00167.jpg
#   inflating: dataset/celeba_hq_256/00168.jpg
#   inflating: dataset/celeba_hq_256/00169.jpg
#   inflating: dataset/celeba_hq_256/00170.jpg
#   inflating: dataset/celeba_hq_256/00171.jpg
#   inflating: dataset/celeba_hq_256/00172.jpg
#   inflating: dataset/celeba_hq_256/00173.jpg
#   inflating: dataset/celeba_hq_256/00174.jpg
#   inflating: dataset/celeba_hq_256/00175.jpg
#   inflating: dataset/celeba_hq_256/00176.jpg
#   inflating: dataset/celeba_hq_256/00177.jpg
#   inflating: dataset/celeba_hq_256/00178.jpg
#   inflating: dataset/celeba_hq_256/00179.jpg
#   inflating: dataset/celeba_hq_256/00180.jpg
#   inflating: dataset/celeba_hq_256/00181.jpg
#   inflating: dataset/celeba_hq_256/00182.jpg
#   inflating: dataset/celeba_hq_256/00183.jpg
#   inflating: dataset/celeba_hq_256/00184.jpg
#   inflating: dataset/celeba_hq_256/00185.jpg
#   inflating: dataset/celeba_hq_256/00186.jpg
#   inflating: dataset/celeba_hq_256/00187.jpg
#   inflating: dataset/celeba_hq_256/00188.jpg
#   inflating: dataset/celeba_hq_256/00189.jpg
#   inflating: dataset/celeba_hq_256/00190.jpg
#   inflating: dataset/celeba_hq_256/00191.jpg
#   inflating: dataset/celeba_hq_256/00192.jpg
#   inflating: dataset/celeba_hq_256/00193.jpg
#   inflating: dataset/celeba_hq_256/00194.jpg
#   inflating: dataset/celeba_hq_256/00195.jpg
#   inflating: dataset/celeba_hq_256/00196.jpg
#   inflating: dataset/celeba_hq_256/00197.jpg
#   inflating: dataset/celeba_hq_256/00198.jpg
#   inflating: dataset/celeba_hq_256/00199.jpg
#   inflating: dataset/celeba_hq_256/00200.jpg
#   inflating: dataset/celeba_hq_256/00201.jpg
#   inflating: dataset/celeba_hq_256/00202.jpg
#   inflating: dataset/celeba_hq_256/00203.jpg
#   inflating: dataset/celeba_hq_256/00204.jpg
#   inflating: dataset/celeba_hq_256/00205.jpg
#   inflating: dataset/celeba_hq_256/00206.jpg
#   inflating: dataset/celeba_hq_256/00207.jpg
#   inflating: dataset/celeba_hq_256/00208.jpg
#   inflating: dataset/celeba_hq_256/00209.jpg
#   inflating: dataset/celeba_hq_256/00210.jpg
#   inflating: dataset/celeba_hq_256/00211.jpg
#   inflating: dataset/celeba_hq_256/00212.jpg
#   inflating: dataset/celeba_hq_256/00213.jpg
#   inflating: dataset/celeba_hq_256/00214.jpg
#   inflating: dataset/celeba_hq_256/00215.jpg
#   inflating: dataset/celeba_hq_256/00216.jpg
#   inflating: dataset/celeba_hq_256/00217.jpg
#   inflating: dataset/celeba_hq_256/00218.jpg
#   inflating: dataset/celeba_hq_256/00219.jpg
#   inflating: dataset/celeba_hq_256/00220.jpg
#   inflating: dataset/celeba_hq_256/00221.jpg
#   inflating: dataset/celeba_hq_256/00222.jpg
#   inflating: dataset/celeba_hq_256/00223.jpg
#   inflating: dataset/celeba_hq_256/00224.jpg
#   inflating: dataset/celeba_hq_256/00225.jpg
#   inflating: dataset/celeba_hq_256/00226.jpg
#   inflating: dataset/celeba_hq_256/00227.jpg
#   inflating: dataset/celeba_hq_256/00228.jpg
#   inflating: dataset/celeba_hq_256/00229.jpg
#   inflating: dataset/celeba_hq_256/00230.jpg
#   inflating: dataset/celeba_hq_256/00231.jpg
#   inflating: dataset/celeba_hq_256/00232.jpg
#   inflating: dataset/celeba_hq_256/00233.jpg
#   inflating: dataset/celeba_hq_256/00234.jpg
#   inflating: dataset/celeba_hq_256/00235.jpg
#   inflating: dataset/celeba_hq_256/00236.jpg
#   inflating: dataset/celeba_hq_256/00237.jpg
#   inflating: dataset/celeba_hq_256/00238.jpg
#   inflating: dataset/celeba_hq_256/00239.jpg
#   inflating: dataset/celeba_hq_256/00240.jpg
#   inflating: dataset/celeba_hq_256/00241.jpg
#   inflating: dataset/celeba_hq_256/00242.jpg
#   inflating: dataset/celeba_hq_256/00243.jpg
#   inflating: dataset/celeba_hq_256/00244.jpg
#   inflating: dataset/celeba_hq_256/00245.jpg
#   inflating: dataset/celeba_hq_256/00246.jpg
#   inflating: dataset/celeba_hq_256/00247.jpg
#   inflating: dataset/celeba_hq_256/00248.jpg
#   inflating: dataset/celeba_hq_256/00249.jpg
#   inflating: dataset/celeba_hq_256/00250.jpg
#   inflating: dataset/celeba_hq_256/00251.jpg
#   inflating: dataset/celeba_hq_256/00252.jpg
#   inflating: dataset/celeba_hq_256/00253.jpg
#   inflating: dataset/celeba_hq_256/00254.jpg
#   inflating: dataset/celeba_hq_256/00255.jpg
#   inflating: dataset/celeba_hq_256/00256.jpg
#   inflating: dataset/celeba_hq_256/00257.jpg
#   inflating: dataset/celeba_hq_256/00258.jpg
#   inflating: dataset/celeba_hq_256/00259.jpg
#   inflating: dataset/celeba_hq_256/00260.jpg
#   inflating: dataset/celeba_hq_256/00261.jpg
#   inflating: dataset/celeba_hq_256/00262.jpg
#   inflating: dataset/celeba_hq_256/00263.jpg
#   inflating: dataset/celeba_hq_256/00264.jpg
#   inflating: dataset/celeba_hq_256/00265.jpg
#   inflating: dataset/celeba_hq_256/00266.jpg
#   inflating: dataset/celeba_hq_256/00267.jpg
#   inflating: dataset/celeba_hq_256/00268.jpg
#   inflating: dataset/celeba_hq_256/00269.jpg
#   inflating: dataset/celeba_hq_256/00270.jpg
#   inflating: dataset/celeba_hq_256/00271.jpg
#   inflating: dataset/celeba_hq_256/00272.jpg
#   inflating: dataset/celeba_hq_256/00273.jpg
#   inflating: dataset/celeba_hq_256/00274.jpg
#   inflating: dataset/celeba_hq_256/00275.jpg
#   inflating: dataset/celeba_hq_256/00276.jpg
#   inflating: dataset/celeba_hq_256/00277.jpg
#   inflating: dataset/celeba_hq_256/00278.jpg
#   inflating: dataset/celeba_hq_256/00279.jpg
#   inflating: dataset/celeba_hq_256/00280.jpg
#   inflating: dataset/celeba_hq_256/00281.jpg
#   inflating: dataset/celeba_hq_256/00282.jpg
#   inflating: dataset/celeba_hq_256/00283.jpg
#   inflating: dataset/celeba_hq_256/00284.jpg
#   inflating: dataset/celeba_hq_256/00285.jpg
#   inflating: dataset/celeba_hq_256/00286.jpg
#   inflating: dataset/celeba_hq_256/00287.jpg
#   inflating: dataset/celeba_hq_256/00288.jpg
#   inflating: dataset/celeba_hq_256/00289.jpg
#   inflating: dataset/celeba_hq_256/00290.jpg
#   inflating: dataset/celeba_hq_256/00291.jpg
#   inflating: dataset/celeba_hq_256/00292.jpg
#   inflating: dataset/celeba_hq_256/00293.jpg
#   inflating: dataset/celeba_hq_256/00294.jpg
#   inflating: dataset/celeba_hq_256/00295.jpg
#   inflating: dataset/celeba_hq_256/00296.jpg
#   inflating: dataset/celeba_hq_256/00297.jpg
#   inflating: dataset/celeba_hq_256/00298.jpg
#   inflating: dataset/celeba_hq_256/00299.jpg
#   inflating: dataset/celeba_hq_256/00300.jpg
#   inflating: dataset/celeba_hq_256/00301.jpg
#   inflating: dataset/celeba_hq_256/00302.jpg
#   inflating: dataset/celeba_hq_256/00303.jpg
#   inflating: dataset/celeba_hq_256/00304.jpg
#   inflating: dataset/celeba_hq_256/00305.jpg
#   inflating: dataset/celeba_hq_256/00306.jpg
#   inflating: dataset/celeba_hq_256/00307.jpg
#   inflating: dataset/celeba_hq_256/00308.jpg
#   inflating: dataset/celeba_hq_256/00309.jpg
#   inflating: dataset/celeba_hq_256/00310.jpg
#   inflating: dataset/celeba_hq_256/00311.jpg
#   inflating: dataset/celeba_hq_256/00312.jpg
#   inflating: dataset/celeba_hq_256/00313.jpg
#   inflating: dataset/celeba_hq_256/00314.jpg
#   inflating: dataset/celeba_hq_256/00315.jpg
#   inflating: dataset/celeba_hq_256/00316.jpg
#   inflating: dataset/celeba_hq_256/00317.jpg
#   inflating: dataset/celeba_hq_256/00318.jpg
#   inflating: dataset/celeba_hq_256/00319.jpg
#   inflating: dataset/celeba_hq_256/00320.jpg
#   inflating: dataset/celeba_hq_256/00321.jpg
#   inflating: dataset/celeba_hq_256/00322.jpg
#   inflating: dataset/celeba_hq_256/00323.jpg
#   inflating: dataset/celeba_hq_256/00324.jpg
#   inflating: dataset/celeba_hq_256/00325.jpg
#   inflating: dataset/celeba_hq_256/00326.jpg
#   inflating: dataset/celeba_hq_256/00327.jpg
#   inflating: dataset/celeba_hq_256/00328.jpg
#   inflating: dataset/celeba_hq_256/00329.jpg
#   inflating: dataset/celeba_hq_256/00330.jpg
#   inflating: dataset/celeba_hq_256/00331.jpg
#   inflating: dataset/celeba_hq_256/00332.jpg
#   inflating: dataset/celeba_hq_256/00333.jpg
#   inflating: dataset/celeba_hq_256/00334.jpg
#   inflating: dataset/celeba_hq_256/00335.jpg
#   inflating: dataset/celeba_hq_256/00336.jpg
#   inflating: dataset/celeba_hq_256/00337.jpg
#   inflating: dataset/celeba_hq_256/00338.jpg
#   inflating: dataset/celeba_hq_256/00339.jpg
#   inflating: dataset/celeba_hq_256/00340.jpg
#   inflating: dataset/celeba_hq_256/00341.jpg
#   inflating: dataset/celeba_hq_256/00342.jpg
#   inflating: dataset/celeba_hq_256/00343.jpg
#   inflating: dataset/celeba_hq_256/00344.jpg
#   inflating: dataset/celeba_hq_256/00345.jpg
#   inflating: dataset/celeba_hq_256/00346.jpg
#   inflating: dataset/celeba_hq_256/00347.jpg
#   inflating: dataset/celeba_hq_256/00348.jpg
#   inflating: dataset/celeba_hq_256/00349.jpg
#   inflating: dataset/celeba_hq_256/00350.jpg
#   inflating: dataset/celeba_hq_256/00351.jpg
#   inflating: dataset/celeba_hq_256/00352.jpg
#   inflating: dataset/celeba_hq_256/00353.jpg
#   inflating: dataset/celeba_hq_256/00354.jpg
#   inflating: dataset/celeba_hq_256/00355.jpg
#   inflating: dataset/celeba_hq_256/00356.jpg
#   inflating: dataset/celeba_hq_256/00357.jpg
#   inflating: dataset/celeba_hq_256/00358.jpg
#   inflating: dataset/celeba_hq_256/00359.jpg
#   inflating: dataset/celeba_hq_256/00360.jpg
#   inflating: dataset/celeba_hq_256/00361.jpg
#   inflating: dataset/celeba_hq_256/00362.jpg
#   inflating: dataset/celeba_hq_256/00363.jpg
#   inflating: dataset/celeba_hq_256/00364.jpg
#   inflating: dataset/celeba_hq_256/00365.jpg
#   inflating: dataset/celeba_hq_256/00366.jpg
#   inflating: dataset/celeba_hq_256/00367.jpg
#   inflating: dataset/celeba_hq_256/00368.jpg
#   inflating: dataset/celeba_hq_256/00369.jpg
#   inflating: dataset/celeba_hq_256/00370.jpg
#   inflating: dataset/celeba_hq_256/00371.jpg
#   inflating: dataset/celeba_hq_256/00372.jpg
#   inflating: dataset/celeba_hq_256/00373.jpg
#   inflating: dataset/celeba_hq_256/00374.jpg
#   inflating: dataset/celeba_hq_256/00375.jpg
#   inflating: dataset/celeba_hq_256/00376.jpg
#   inflating: dataset/celeba_hq_256/00377.jpg
#   inflating: dataset/celeba_hq_256/00378.jpg
#   inflating: dataset/celeba_hq_256/00379.jpg
#   inflating: dataset/celeba_hq_256/00380.jpg
#   inflating: dataset/celeba_hq_256/00381.jpg
#   inflating: dataset/celeba_hq_256/00382.jpg
#   inflating: dataset/celeba_hq_256/00383.jpg
#   inflating: dataset/celeba_hq_256/00384.jpg
#   inflating: dataset/celeba_hq_256/00385.jpg
#   inflating: dataset/celeba_hq_256/00386.jpg
#   inflating: dataset/celeba_hq_256/00387.jpg
#   inflating: dataset/celeba_hq_256/00388.jpg
#   inflating: dataset/celeba_hq_256/00389.jpg
#   inflating: dataset/celeba_hq_256/00390.jpg
#   inflating: dataset/celeba_hq_256/00391.jpg
#   inflating: dataset/celeba_hq_256/00392.jpg
#   inflating: dataset/celeba_hq_256/00393.jpg
#   inflating: dataset/celeba_hq_256/00394.jpg
#   inflating: dataset/celeba_hq_256/00395.jpg
#   inflating: dataset/celeba_hq_256/00396.jpg
#   inflating: dataset/celeba_hq_256/00397.jpg
#   inflating: dataset/celeba_hq_256/00398.jpg
#   inflating: dataset/celeba_hq_256/00399.jpg
#   inflating: dataset/celeba_hq_256/00400.jpg
#   inflating: dataset/celeba_hq_256/00401.jpg
#   inflating: dataset/celeba_hq_256/00402.jpg
#   inflating: dataset/celeba_hq_256/00403.jpg
#   inflating: dataset/celeba_hq_256/00404.jpg
#   inflating: dataset/celeba_hq_256/00405.jpg
#   inflating: dataset/celeba_hq_256/00406.jpg
#   inflating: dataset/celeba_hq_256/00407.jpg
#   inflating: dataset/celeba_hq_256/00408.jpg
#   inflating: dataset/celeba_hq_256/00409.jpg
#   inflating: dataset/celeba_hq_256/00410.jpg
#   inflating: dataset/celeba_hq_256/00411.jpg
#   inflating: dataset/celeba_hq_256/00412.jpg
#   inflating: dataset/celeba_hq_256/00413.jpg
#   inflating: dataset/celeba_hq_256/00414.jpg
#   inflating: dataset/celeba_hq_256/00415.jpg
#   inflating: dataset/celeba_hq_256/00416.jpg
#   inflating: dataset/celeba_hq_256/00417.jpg
#   inflating: dataset/celeba_hq_256/00418.jpg
#   inflating: dataset/celeba_hq_256/00419.jpg
#   inflating: dataset/celeba_hq_256/00420.jpg
#   inflating: dataset/celeba_hq_256/00421.jpg
#   inflating: dataset/celeba_hq_256/00422.jpg
#   inflating: dataset/celeba_hq_256/00423.jpg
#   inflating: dataset/celeba_hq_256/00424.jpg
#   inflating: dataset/celeba_hq_256/00425.jpg
#   inflating: dataset/celeba_hq_256/00426.jpg
#   inflating: dataset/celeba_hq_256/00427.jpg
#   inflating: dataset/celeba_hq_256/00428.jpg
#   inflating: dataset/celeba_hq_256/00429.jpg
#   inflating: dataset/celeba_hq_256/00430.jpg
#   inflating: dataset/celeba_hq_256/00431.jpg
#   inflating: dataset/celeba_hq_256/00432.jpg
#   inflating: dataset/celeba_hq_256/00433.jpg
#   inflating: dataset/celeba_hq_256/00434.jpg
#   inflating: dataset/celeba_hq_256/00435.jpg
#   inflating: dataset/celeba_hq_256/00436.jpg
#   inflating: dataset/celeba_hq_256/00437.jpg
#   inflating: dataset/celeba_hq_256/00438.jpg
#   inflating: dataset/celeba_hq_256/00439.jpg
#   inflating: dataset/celeba_hq_256/00440.jpg
#   inflating: dataset/celeba_hq_256/00441.jpg
#   inflating: dataset/celeba_hq_256/00442.jpg
#   inflating: dataset/celeba_hq_256/00443.jpg
#   inflating: dataset/celeba_hq_256/00444.jpg
#   inflating: dataset/celeba_hq_256/00445.jpg
#   inflating: dataset/celeba_hq_256/00446.jpg
#   inflating: dataset/celeba_hq_256/00447.jpg
#   inflating: dataset/celeba_hq_256/00448.jpg
#   inflating: dataset/celeba_hq_256/00449.jpg
#   inflating: dataset/celeba_hq_256/00450.jpg
#   inflating: dataset/celeba_hq_256/00451.jpg
#   inflating: dataset/celeba_hq_256/00452.jpg
#   inflating: dataset/celeba_hq_256/00453.jpg
#   inflating: dataset/celeba_hq_256/00454.jpg
#   inflating: dataset/celeba_hq_256/00455.jpg
#   inflating: dataset/celeba_hq_256/00456.jpg
#   inflating: dataset/celeba_hq_256/00457.jpg
#   inflating: dataset/celeba_hq_256/00458.jpg
#   inflating: dataset/celeba_hq_256/00459.jpg
#   inflating: dataset/celeba_hq_256/00460.jpg
#   inflating: dataset/celeba_hq_256/00461.jpg
#   inflating: dataset/celeba_hq_256/00462.jpg
#   inflating: dataset/celeba_hq_256/00463.jpg
#   inflating: dataset/celeba_hq_256/00464.jpg
#   inflating: dataset/celeba_hq_256/00465.jpg
#   inflating: dataset/celeba_hq_256/00466.jpg
#   inflating: dataset/celeba_hq_256/00467.jpg
#   inflating: dataset/celeba_hq_256/00468.jpg
#   inflating: dataset/celeba_hq_256/00469.jpg
#   inflating: dataset/celeba_hq_256/00470.jpg
#   inflating: dataset/celeba_hq_256/00471.jpg
#   inflating: dataset/celeba_hq_256/00472.jpg
#   inflating: dataset/celeba_hq_256/00473.jpg
#   inflating: dataset/celeba_hq_256/00474.jpg
#   inflating: dataset/celeba_hq_256/00475.jpg
#   inflating: dataset/celeba_hq_256/00476.jpg
#   inflating: dataset/celeba_hq_256/00477.jpg
#   inflating: dataset/celeba_hq_256/00478.jpg
#   inflating: dataset/celeba_hq_256/00479.jpg
#   inflating: dataset/celeba_hq_256/00480.jpg
#   inflating: dataset/celeba_hq_256/00481.jpg
#   inflating: dataset/celeba_hq_256/00482.jpg
#   inflating: dataset/celeba_hq_256/00483.jpg
#   inflating: dataset/celeba_hq_256/00484.jpg
#   inflating: dataset/celeba_hq_256/00485.jpg
#   inflating: dataset/celeba_hq_256/00486.jpg
#   inflating: dataset/celeba_hq_256/00487.jpg
#   inflating: dataset/celeba_hq_256/00488.jpg
#   inflating: dataset/celeba_hq_256/00489.jpg
#   inflating: dataset/celeba_hq_256/00490.jpg
#   inflating: dataset/celeba_hq_256/00491.jpg
#   inflating: dataset/celeba_hq_256/00492.jpg
#   inflating: dataset/celeba_hq_256/00493.jpg
#   inflating: dataset/celeba_hq_256/00494.jpg
#   inflating: dataset/celeba_hq_256/00495.jpg
#   inflating: dataset/celeba_hq_256/00496.jpg
#   inflating: dataset/celeba_hq_256/00497.jpg
#   inflating: dataset/celeba_hq_256/00498.jpg
#   inflating: dataset/celeba_hq_256/00499.jpg
#   inflating: dataset/celeba_hq_256/00500.jpg
#   inflating: dataset/celeba_hq_256/00501.jpg
#   inflating: dataset/celeba_hq_256/00502.jpg
#   inflating: dataset/celeba_hq_256/00503.jpg
#   inflating: dataset/celeba_hq_256/00504.jpg
#   inflating: dataset/celeba_hq_256/00505.jpg
#   inflating: dataset/celeba_hq_256/00506.jpg
#   inflating: dataset/celeba_hq_256/00507.jpg
#   inflating: dataset/celeba_hq_256/00508.jpg
#   inflating: dataset/celeba_hq_256/00509.jpg
#   inflating: dataset/celeba_hq_256/00510.jpg
#   inflating: dataset/celeba_hq_256/00511.jpg
#   inflating: dataset/celeba_hq_256/00512.jpg
#   inflating: dataset/celeba_hq_256/00513.jpg
#   inflating: dataset/celeba_hq_256/00514.jpg
#   inflating: dataset/celeba_hq_256/00515.jpg
#   inflating: dataset/celeba_hq_256/00516.jpg
#   inflating: dataset/celeba_hq_256/00517.jpg
#   inflating: dataset/celeba_hq_256/00518.jpg
#   inflating: dataset/celeba_hq_256/00519.jpg
#   inflating: dataset/celeba_hq_256/00520.jpg
#   inflating: dataset/celeba_hq_256/00521.jpg
#   inflating: dataset/celeba_hq_256/00522.jpg
#   inflating: dataset/celeba_hq_256/00523.jpg
#   inflating: dataset/celeba_hq_256/00524.jpg
#   inflating: dataset/celeba_hq_256/00525.jpg
#   inflating: dataset/celeba_hq_256/00526.jpg
#   inflating: dataset/celeba_hq_256/00527.jpg
#   inflating: dataset/celeba_hq_256/00528.jpg
#   inflating: dataset/celeba_hq_256/00529.jpg
#   inflating: dataset/celeba_hq_256/00530.jpg
#   inflating: dataset/celeba_hq_256/00531.jpg
#   inflating: dataset/celeba_hq_256/00532.jpg
#   inflating: dataset/celeba_hq_256/00533.jpg
#   inflating: dataset/celeba_hq_256/00534.jpg
#   inflating: dataset/celeba_hq_256/00535.jpg
#   inflating: dataset/celeba_hq_256/00536.jpg
#   inflating: dataset/celeba_hq_256/00537.jpg
#   inflating: dataset/celeba_hq_256/00538.jpg
#   inflating: dataset/celeba_hq_256/00539.jpg
#   inflating: dataset/celeba_hq_256/00540.jpg
#   inflating: dataset/celeba_hq_256/00541.jpg
#   inflating: dataset/celeba_hq_256/00542.jpg
#   inflating: dataset/celeba_hq_256/00543.jpg
#   inflating: dataset/celeba_hq_256/00544.jpg
#   inflating: dataset/celeba_hq_256/00545.jpg
#   inflating: dataset/celeba_hq_256/00546.jpg
#   inflating: dataset/celeba_hq_256/00547.jpg
#   inflating: dataset/celeba_hq_256/00548.jpg
#   inflating: dataset/celeba_hq_256/00549.jpg
#   inflating: dataset/celeba_hq_256/00550.jpg
#   inflating: dataset/celeba_hq_256/00551.jpg
#   inflating: dataset/celeba_hq_256/00552.jpg
#   inflating: dataset/celeba_hq_256/00553.jpg
#   inflating: dataset/celeba_hq_256/00554.jpg
#   inflating: dataset/celeba_hq_256/00555.jpg
#   inflating: dataset/celeba_hq_256/00556.jpg
#   inflating: dataset/celeba_hq_256/00557.jpg
#   inflating: dataset/celeba_hq_256/00558.jpg
#   inflating: dataset/celeba_hq_256/00559.jpg
#   inflating: dataset/celeba_hq_256/00560.jpg
#   inflating: dataset/celeba_hq_256/00561.jpg
#   inflating: dataset/celeba_hq_256/00562.jpg
#   inflating: dataset/celeba_hq_256/00563.jpg
#   inflating: dataset/celeba_hq_256/00564.jpg
#   inflating: dataset/celeba_hq_256/00565.jpg
#   inflating: dataset/celeba_hq_256/00566.jpg
#   inflating: dataset/celeba_hq_256/00567.jpg
#   inflating: dataset/celeba_hq_256/00568.jpg
#   inflating: dataset/celeba_hq_256/00569.jpg
#   inflating: dataset/celeba_hq_256/00570.jpg
#   inflating: dataset/celeba_hq_256/00571.jpg
#   inflating: dataset/celeba_hq_256/00572.jpg
#   inflating: dataset/celeba_hq_256/00573.jpg
#   inflating: dataset/celeba_hq_256/00574.jpg
#   inflating: dataset/celeba_hq_256/00575.jpg
#   inflating: dataset/celeba_hq_256/00576.jpg
#   inflating: dataset/celeba_hq_256/00577.jpg
#   inflating: dataset/celeba_hq_256/00578.jpg
#   inflating: dataset/celeba_hq_256/00579.jpg
#   inflating: dataset/celeba_hq_256/00580.jpg
#   inflating: dataset/celeba_hq_256/00581.jpg
#   inflating: dataset/celeba_hq_256/00582.jpg
#   inflating: dataset/celeba_hq_256/00583.jpg
#   inflating: dataset/celeba_hq_256/00584.jpg
#   inflating: dataset/celeba_hq_256/00585.jpg
#   inflating: dataset/celeba_hq_256/00586.jpg
#   inflating: dataset/celeba_hq_256/00587.jpg
#   inflating: dataset/celeba_hq_256/00588.jpg
#   inflating: dataset/celeba_hq_256/00589.jpg
#   inflating: dataset/celeba_hq_256/00590.jpg
#   inflating: dataset/celeba_hq_256/00591.jpg
#   inflating: dataset/celeba_hq_256/00592.jpg
#   inflating: dataset/celeba_hq_256/00593.jpg
#   inflating: dataset/celeba_hq_256/00594.jpg
#   inflating: dataset/celeba_hq_256/00595.jpg
#   inflating: dataset/celeba_hq_256/00596.jpg
#   inflating: dataset/celeba_hq_256/00597.jpg
#   inflating: dataset/celeba_hq_256/00598.jpg
#   inflating: dataset/celeba_hq_256/00599.jpg
#   inflating: dataset/celeba_hq_256/00600.jpg
#   inflating: dataset/celeba_hq_256/00601.jpg
#   inflating: dataset/celeba_hq_256/00602.jpg
#   inflating: dataset/celeba_hq_256/00603.jpg
#   inflating: dataset/celeba_hq_256/00604.jpg
#   inflating: dataset/celeba_hq_256/00605.jpg
#   inflating: dataset/celeba_hq_256/00606.jpg
#   inflating: dataset/celeba_hq_256/00607.jpg
#   inflating: dataset/celeba_hq_256/00608.jpg
#   inflating: dataset/celeba_hq_256/00609.jpg
#   inflating: dataset/celeba_hq_256/00610.jpg
#   inflating: dataset/celeba_hq_256/00611.jpg
#   inflating: dataset/celeba_hq_256/00612.jpg
#   inflating: dataset/celeba_hq_256/00613.jpg
#   inflating: dataset/celeba_hq_256/00614.jpg
#   inflating: dataset/celeba_hq_256/00615.jpg
#   inflating: dataset/celeba_hq_256/00616.jpg
#   inflating: dataset/celeba_hq_256/00617.jpg
#   inflating: dataset/celeba_hq_256/00618.jpg
#   inflating: dataset/celeba_hq_256/00619.jpg
#   inflating: dataset/celeba_hq_256/00620.jpg
#   inflating: dataset/celeba_hq_256/00621.jpg
#   inflating: dataset/celeba_hq_256/00622.jpg
#   inflating: dataset/celeba_hq_256/00623.jpg
#   inflating: dataset/celeba_hq_256/00624.jpg
#   inflating: dataset/celeba_hq_256/00625.jpg
#   inflating: dataset/celeba_hq_256/00626.jpg
#   inflating: dataset/celeba_hq_256/00627.jpg
#   inflating: dataset/celeba_hq_256/00628.jpg
#   inflating: dataset/celeba_hq_256/00629.jpg
#   inflating: dataset/celeba_hq_256/00630.jpg
#   inflating: dataset/celeba_hq_256/00631.jpg
#   inflating: dataset/celeba_hq_256/00632.jpg
#   inflating: dataset/celeba_hq_256/00633.jpg
#   inflating: dataset/celeba_hq_256/00634.jpg
#   inflating: dataset/celeba_hq_256/00635.jpg
#   inflating: dataset/celeba_hq_256/00636.jpg
#   inflating: dataset/celeba_hq_256/00637.jpg
#   inflating: dataset/celeba_hq_256/00638.jpg
#   inflating: dataset/celeba_hq_256/00639.jpg
#   inflating: dataset/celeba_hq_256/00640.jpg
#   inflating: dataset/celeba_hq_256/00641.jpg
#   inflating: dataset/celeba_hq_256/00642.jpg
#   inflating: dataset/celeba_hq_256/00643.jpg
#   inflating: dataset/celeba_hq_256/00644.jpg
#   inflating: dataset/celeba_hq_256/00645.jpg
#   inflating: dataset/celeba_hq_256/00646.jpg
#   inflating: dataset/celeba_hq_256/00647.jpg
#   inflating: dataset/celeba_hq_256/00648.jpg
#   inflating: dataset/celeba_hq_256/00649.jpg
#   inflating: dataset/celeba_hq_256/00650.jpg
#   inflating: dataset/celeba_hq_256/00651.jpg
#   inflating: dataset/celeba_hq_256/00652.jpg
#   inflating: dataset/celeba_hq_256/00653.jpg
#   inflating: dataset/celeba_hq_256/00654.jpg
#   inflating: dataset/celeba_hq_256/00655.jpg
#   inflating: dataset/celeba_hq_256/00656.jpg
#   inflating: dataset/celeba_hq_256/00657.jpg
#   inflating: dataset/celeba_hq_256/00658.jpg
#   inflating: dataset/celeba_hq_256/00659.jpg
#   inflating: dataset/celeba_hq_256/00660.jpg
#   inflating: dataset/celeba_hq_256/00661.jpg
#   inflating: dataset/celeba_hq_256/00662.jpg
#   inflating: dataset/celeba_hq_256/00663.jpg
#   inflating: dataset/celeba_hq_256/00664.jpg
#   inflating: dataset/celeba_hq_256/00665.jpg
#   inflating: dataset/celeba_hq_256/00666.jpg
#   inflating: dataset/celeba_hq_256/00667.jpg
#   inflating: dataset/celeba_hq_256/00668.jpg
#   inflating: dataset/celeba_hq_256/00669.jpg
#   inflating: dataset/celeba_hq_256/00670.jpg

# %% [markdown]
# A continuación se definira el objeto que se encargara de gestionar nuestro dataset. El manejo de datasets necesita realizar las siguientes acciones:
#
#
# 1.   Leer el archivo desde el fichero, hacia la memoria RAM del computados, para esto se utilizara la libreria PIL ya que leeremos imagenes jpg, las primeras dos lineas de la funcion __getitem__, la primera linea gestiona la ruta en el directorio y la segundo carga el archivo a la variable image.
# 2.   Procesar la imagen para ser utilizara por pytorch. Esn este caso uno puede procesar la imagen cambiando el tamaño, cortar, cambiar color etc. En este ejemplo la unica operacion sera convertir la imagen PIL a tensor.
#
# 3.   Como nuestro dataset solo tiene imagenes sin corromper por el desenfoque, debemos crear una version del dataset que tenga las mismas imagenes corrompidas, para eso son las siguientes lineas de la clase CustomDataset.
#
#
# Una vez creada y declarada la clase, este objeto se encarga de realizar la gestion de batch, es decir enviar una porcion aleatoria del dataset, esto a fin de no saturar la memoria de video. El parametro batch_size se puede declarar cuantas imagenes del dataset se cargaran cada vez.
#
# Como ejemplo al final de esta celda se llaman y plotean algunas imagenes del dataset a traves del objeto.

# %%
import os
import glob
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torch.nn.functional as F

class CustomDataset(Dataset):
    def __init__(self, data_dir):
        self.data_dir = data_dir
        self.image_paths = glob.glob(os.path.join(data_dir, "*.jpg"))

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path)

        transform = transforms.Compose([
            transforms.ToTensor()
        ])

        image = transform(image)
        kernel =  torch.eye(7)/7
        kernel = torch.unsqueeze(torch.unsqueeze(kernel,0),0).float()
        pad = 7//2
        corrR = F.conv2d(image.unsqueeze(0)[:,0:1],kernel,padding=pad)
        corrG = F.conv2d(image.unsqueeze(0)[:,1:2],kernel,padding=pad)
        corrB = F.conv2d(image.unsqueeze(0)[:,2:],kernel,padding=pad)
        corrupted = torch.cat((corrR,corrG,corrB),dim=1)
        return image,corrupted[0]


dataset = CustomDataset("dataset/celeba_hq_256/")

batch_size = 32  # Adjust this based on your system's memory
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
cont=0
for batch in dataloader:
  plot_tensor(torch.cat((batch[0],batch[1]),dim=3))
  cont +=1
  if cont == 5:
    break

# %%
import torch.nn as nn
import numpy as np
from PIL import Image
device = torch.device('cuda')

class UNetBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(UNetBlock, self).__init__()

        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        out = self.encoder(x)
        out = self.decoder(out)
        return out

# U-Net
class UNet(nn.Module):
    def __init__(self, in_channels=3, out_channels=3, num_blocks=2):
        super(UNet, self).__init__()

        # Contracting Path (Encoder)
        self.encoder_blocks = nn.ModuleList()
        for _ in range(num_blocks):
            self.encoder_blocks.append(UNetBlock(in_channels, 64))
            in_channels = 64

        # Bottleneck
        self.bottleneck = UNetBlock(64,64)

        # Expansive Path (Decoder)
        self.decoder_blocks = nn.ModuleList()
        for _ in range(num_blocks):
            self.decoder_blocks.append(UNetBlock(64 * 2, 64))  # Concatenate skip connection

        # Final convolutional layer
        self.final_conv = nn.Conv2d(64, out_channels, kernel_size=1)

    def forward(self, x):
        skip_connections = []

        # Encoder
        for block in self.encoder_blocks:
            x = block(x)
            skip_connections.append(x)
            x = nn.functional.max_pool2d(x, kernel_size=2, stride=2)

        # Bottleneck
        x = self.bottleneck(x)

        # Decoder
        for block in self.decoder_blocks:
            skip = skip_connections.pop()
            x = nn.functional.interpolate(x, scale_factor=2, mode='bilinear', align_corners=True)
            x = torch.cat([x, skip], dim=1)
            x = block(x)

        # Final convolution
        x = self.final_conv(x)
        return x


lamb = 0.0001
Epochs = 160

# Parametros del entrenamiento
model = UNet().to(device)
loss = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lamb)
loss_val = []
for epo in range(1,Epochs+1):

  for batch in dataloader:

    corrompida = batch[1].to(device)
    original   = batch[0].to(device)

    # propagacion al modelo
    out_tensor = model(corrompida)
    # Calcular error
    L = loss(original,out_tensor)
    #Obtener gradientes
    L.backward()

    # update weights
    optimizer.step()

    # zero the gradients after updating
    optimizer.zero_grad()

    # Guardar valores de loss por epoca
    loss_val.append(L.item())

  if epo % 20 == 0 and epo>40:
    lamb = lamb*0.90
    optimizer = torch.optim.Adam(model.parameters(), lr=lamb)
  print(f" epoca {epo} Loss = {L.item():.6f} - learning_rate = {lamb:.8f}")


    # Use the batch of tensors for training
# Out:
#  epoca 1 Loss = 0.251353 - learning_rate = 0.00010000
#  epoca 2 Loss = 0.038450 - learning_rate = 0.00010000
#  epoca 3 Loss = 0.015218 - learning_rate = 0.00010000
#  epoca 4 Loss = 0.014286 - learning_rate = 0.00010000
#  epoca 5 Loss = 0.013043 - learning_rate = 0.00010000
#  epoca 6 Loss = 0.009847 - learning_rate = 0.00010000
#  epoca 7 Loss = 0.010997 - learning_rate = 0.00010000
#  epoca 8 Loss = 0.008890 - learning_rate = 0.00010000
#  epoca 9 Loss = 0.005608 - learning_rate = 0.00010000
#  epoca 10 Loss = 0.004161 - learning_rate = 0.00010000
#  epoca 11 Loss = 0.003678 - learning_rate = 0.00010000
#  epoca 12 Loss = 0.002622 - learning_rate = 0.00010000
#  epoca 13 Loss = 0.002858 - learning_rate = 0.00010000
#  epoca 14 Loss = 0.002596 - learning_rate = 0.00010000
#  epoca 15 Loss = 0.002449 - learning_rate = 0.00010000
#  epoca 16 Loss = 0.002648 - learning_rate = 0.00010000
#  epoca 17 Loss = 0.002094 - learning_rate = 0.00010000
#  epoca 18 Loss = 0.002194 - learning_rate = 0.00010000
#  epoca 19 Loss = 0.002106 - learning_rate = 0.00010000
#  epoca 20 Loss = 0.002311 - learning_rate = 0.00010000
#  epoca 21 Loss = 0.002105 - learning_rate = 0.00010000
#  epoca 22 Loss = 0.001934 - learning_rate = 0.00010000
#  epoca 23 Loss = 0.002400 - learning_rate = 0.00010000
#  epoca 24 Loss = 0.002442 - learning_rate = 0.00010000
#  epoca 25 Loss = 0.001842 - learning_rate = 0.00010000
#  epoca 26 Loss = 0.001798 - learning_rate = 0.00010000
#  epoca 27 Loss = 0.002547 - learning_rate = 0.00010000
#  epoca 28 Loss = 0.001932 - learning_rate = 0.00010000
#  epoca 29 Loss = 0.001662 - learning_rate = 0.00010000
#  epoca 30 Loss = 0.001885 - learning_rate = 0.00010000
#  epoca 31 Loss = 0.001785 - learning_rate = 0.00010000
#  epoca 32 Loss = 0.001717 - learning_rate = 0.00010000
#  epoca 33 Loss = 0.002127 - learning_rate = 0.00010000
#  epoca 34 Loss = 0.001603 - learning_rate = 0.00010000
#  epoca 35 Loss = 0.001346 - learning_rate = 0.00010000
#  epoca 36 Loss = 0.001919 - learning_rate = 0.00010000
#  epoca 37 Loss = 0.001544 - learning_rate = 0.00010000
#  epoca 38 Loss = 0.001750 - learning_rate = 0.00010000
#  epoca 39 Loss = 0.002120 - learning_rate = 0.00010000
#  epoca 40 Loss = 0.001727 - learning_rate = 0.00010000
#  epoca 41 Loss = 0.001999 - learning_rate = 0.00010000
#  epoca 42 Loss = 0.002426 - learning_rate = 0.00010000
#  epoca 43 Loss = 0.001425 - learning_rate = 0.00010000
#  epoca 44 Loss = 0.001535 - learning_rate = 0.00010000
#  epoca 45 Loss = 0.001715 - learning_rate = 0.00010000
#  epoca 46 Loss = 0.001567 - learning_rate = 0.00010000
#  epoca 47 Loss = 0.001662 - learning_rate = 0.00010000
#  epoca 48 Loss = 0.001431 - learning_rate = 0.00010000
#  epoca 49 Loss = 0.002045 - learning_rate = 0.00010000
#  epoca 50 Loss = 0.001610 - learning_rate = 0.00010000
#  epoca 51 Loss = 0.001413 - learning_rate = 0.00010000
#  epoca 52 Loss = 0.001482 - learning_rate = 0.00010000
#  epoca 53 Loss = 0.001382 - learning_rate = 0.00010000
#  epoca 54 Loss = 0.001972 - learning_rate = 0.00010000
#  epoca 55 Loss = 0.001503 - learning_rate = 0.00010000
#  epoca 56 Loss = 0.001720 - learning_rate = 0.00010000
#  epoca 57 Loss = 0.001448 - learning_rate = 0.00010000
#  epoca 58 Loss = 0.001518 - learning_rate = 0.00010000
#  epoca 59 Loss = 0.002272 - learning_rate = 0.00010000
#  epoca 60 Loss = 0.001245 - learning_rate = 0.00009000
#  epoca 61 Loss = 0.003163 - learning_rate = 0.00009000
#  epoca 62 Loss = 0.002530 - learning_rate = 0.00009000
#  epoca 63 Loss = 0.001942 - learning_rate = 0.00009000
#  epoca 64 Loss = 0.001864 - learning_rate = 0.00009000
#  epoca 65 Loss = 0.001729 - learning_rate = 0.00009000
#  epoca 66 Loss = 0.001637 - learning_rate = 0.00009000
#  epoca 67 Loss = 0.001467 - learning_rate = 0.00009000
#  epoca 68 Loss = 0.001704 - learning_rate = 0.00009000
#  epoca 69 Loss = 0.001473 - learning_rate = 0.00009000
#  epoca 70 Loss = 0.001415 - learning_rate = 0.00009000
#  epoca 71 Loss = 0.001530 - learning_rate = 0.00009000
#  epoca 72 Loss = 0.001286 - learning_rate = 0.00009000
#  epoca 73 Loss = 0.001466 - learning_rate = 0.00009000
#  epoca 74 Loss = 0.001540 - learning_rate = 0.00009000
#  epoca 75 Loss = 0.001446 - learning_rate = 0.00009000
#  epoca 76 Loss = 0.001421 - learning_rate = 0.00009000
#  epoca 77 Loss = 0.001397 - learning_rate = 0.00009000
#  epoca 78 Loss = 0.001197 - learning_rate = 0.00009000
#  epoca 79 Loss = 0.001014 - learning_rate = 0.00009000
#  epoca 80 Loss = 0.001276 - learning_rate = 0.00008100
#  epoca 81 Loss = 0.002535 - learning_rate = 0.00008100
#  epoca 82 Loss = 0.001515 - learning_rate = 0.00008100
#  epoca 83 Loss = 0.001313 - learning_rate = 0.00008100
#  epoca 84 Loss = 0.001179 - learning_rate = 0.00008100
#  epoca 85 Loss = 0.001105 - learning_rate = 0.00008100
#  epoca 86 Loss = 0.001141 - learning_rate = 0.00008100
#  epoca 87 Loss = 0.000999 - learning_rate = 0.00008100
#  epoca 88 Loss = 0.000951 - learning_rate = 0.00008100
#  epoca 89 Loss = 0.001271 - learning_rate = 0.00008100
#  epoca 90 Loss = 0.001181 - learning_rate = 0.00008100
#  epoca 91 Loss = 0.001009 - learning_rate = 0.00008100
#  epoca 92 Loss = 0.001073 - learning_rate = 0.00008100
#  epoca 93 Loss = 0.001027 - learning_rate = 0.00008100
#  epoca 94 Loss = 0.001113 - learning_rate = 0.00008100
#  epoca 95 Loss = 0.000990 - learning_rate = 0.00008100
#  epoca 96 Loss = 0.000948 - learning_rate = 0.00008100
#  epoca 97 Loss = 0.001052 - learning_rate = 0.00008100
#  epoca 98 Loss = 0.000988 - learning_rate = 0.00008100
#  epoca 99 Loss = 0.001360 - learning_rate = 0.00008100
#  epoca 100 Loss = 0.001035 - learning_rate = 0.00007290
#  epoca 101 Loss = 0.001764 - learning_rate = 0.00007290
#  epoca 102 Loss = 0.001378 - learning_rate = 0.00007290
#  epoca 103 Loss = 0.001225 - learning_rate = 0.00007290
#  epoca 104 Loss = 0.001170 - learning_rate = 0.00007290
#  epoca 105 Loss = 0.001008 - learning_rate = 0.00007290
#  epoca 106 Loss = 0.000862 - learning_rate = 0.00007290
#  epoca 107 Loss = 0.000919 - learning_rate = 0.00007290
#  epoca 108 Loss = 0.000995 - learning_rate = 0.00007290
#  epoca 109 Loss = 0.001089 - learning_rate = 0.00007290
#  epoca 110 Loss = 0.001068 - learning_rate = 0.00007290
#  epoca 111 Loss = 0.001181 - learning_rate = 0.00007290
#  epoca 112 Loss = 0.001208 - learning_rate = 0.00007290
#  epoca 113 Loss = 0.001189 - learning_rate = 0.00007290
#  epoca 114 Loss = 0.001159 - learning_rate = 0.00007290
#  epoca 115 Loss = 0.000930 - learning_rate = 0.00007290
#  epoca 116 Loss = 0.000950 - learning_rate = 0.00007290
#  epoca 117 Loss = 0.000945 - learning_rate = 0.00007290
#  epoca 118 Loss = 0.001202 - learning_rate = 0.00007290
#  epoca 119 Loss = 0.001110 - learning_rate = 0.00007290
#  epoca 120 Loss = 0.001149 - learning_rate = 0.00006561
#  epoca 121 Loss = 0.003506 - learning_rate = 0.00006561
#  epoca 122 Loss = 0.001340 - learning_rate = 0.00006561
#  epoca 123 Loss = 0.001081 - learning_rate = 0.00006561
#  epoca 124 Loss = 0.001151 - learning_rate = 0.00006561
#  epoca 125 Loss = 0.001284 - learning_rate = 0.00006561
#  epoca 126 Loss = 0.000915 - learning_rate = 0.00006561
#  epoca 127 Loss = 0.001031 - learning_rate = 0.00006561
#  epoca 128 Loss = 0.000875 - learning_rate = 0.00006561
#  epoca 129 Loss = 0.001067 - learning_rate = 0.00006561
#  epoca 130 Loss = 0.000959 - learning_rate = 0.00006561
#  epoca 131 Loss = 0.000913 - learning_rate = 0.00006561
#  epoca 132 Loss = 0.000981 - learning_rate = 0.00006561
#  epoca 133 Loss = 0.000976 - learning_rate = 0.00006561
#  epoca 134 Loss = 0.000812 - learning_rate = 0.00006561
#  epoca 135 Loss = 0.000915 - learning_rate = 0.00006561
#  epoca 136 Loss = 0.000992 - learning_rate = 0.00006561
#  epoca 137 Loss = 0.000945 - learning_rate = 0.00006561
#  epoca 138 Loss = 0.000885 - learning_rate = 0.00006561
#  epoca 139 Loss = 0.000824 - learning_rate = 0.00006561
#  epoca 140 Loss = 0.000862 - learning_rate = 0.00005905
#  epoca 141 Loss = 0.001598 - learning_rate = 0.00005905
#  epoca 142 Loss = 0.001066 - learning_rate = 0.00005905
#  epoca 143 Loss = 0.001055 - learning_rate = 0.00005905
#  epoca 144 Loss = 0.000935 - learning_rate = 0.00005905
#  epoca 145 Loss = 0.000844 - learning_rate = 0.00005905
#  epoca 146 Loss = 0.000891 - learning_rate = 0.00005905
#  epoca 147 Loss = 0.000918 - learning_rate = 0.00005905
#  epoca 148 Loss = 0.000718 - learning_rate = 0.00005905
#  epoca 149 Loss = 0.000916 - learning_rate = 0.00005905
#  epoca 150 Loss = 0.000804 - learning_rate = 0.00005905
#  epoca 151 Loss = 0.000857 - learning_rate = 0.00005905
#  epoca 152 Loss = 0.000924 - learning_rate = 0.00005905
#  epoca 153 Loss = 0.000862 - learning_rate = 0.00005905
#  epoca 154 Loss = 0.000705 - learning_rate = 0.00005905
#  epoca 155 Loss = 0.000742 - learning_rate = 0.00005905
#  epoca 156 Loss = 0.001023 - learning_rate = 0.00005905
#  epoca 157 Loss = 0.000891 - learning_rate = 0.00005905
#  epoca 158 Loss = 0.000877 - learning_rate = 0.00005905
#  epoca 159 Loss = 0.000714 - learning_rate = 0.00005905
#  epoca 160 Loss = 0.000975 - learning_rate = 0.00005314

# %%
data = np.asarray(image)
input_tensor = torch.from_numpy(data).to(device).float()
# Adaptar dimensioines
input_tensor = torch.unsqueeze(input_tensor,0)
input_tensor = input_tensor.permute(0,3,1,2)

pad = 7//2
kernel =  torch.eye(7).to(device) /7
kernel = torch.unsqueeze(torch.unsqueeze(kernel,0),0).float()

corrR = F.conv2d(input_tensor[:,0:1],kernel,padding=pad)
corrG = F.conv2d(input_tensor[:,1:2],kernel,padding=pad)
corrB = F.conv2d(input_tensor[:,2:],kernel,padding=pad)
corrupted = torch.cat((corrR,corrG,corrB),dim=1)


for param in model.parameters():
    param.requires_grad = False

corrected = model(corrupted.detach())

print("                   Imagen original  -            Imagen distorsionada         -              Reconstruccion de CNN")
plt.figure(figsize=(12, 12))
plot_tensor(torch.cat((input_tensor,corrupted,corrected),dim=3)/255)
# Out:
#                    Imagen original  -            Imagen distorsionada         -              Reconstruccion de CNN
